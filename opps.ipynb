# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh2426226/SD_Devansh_0037/blob/main/opps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class test:
  pass

# %%
a=test()

# %%
type(a)
# Out:
# __main__.test

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class skills:
  def welcome_msg(self):
    print("welcome to skills")

# %%
rohan=skills()

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
rohan.welcome_msg()
# Out:
# welcome to skills

# %%
gaurav=skills()

# %%
gaurav.welcome_msg()
# Out:
# welcome to skills

# %%
class skills1:
    def __init__(self,phone_number,email_id,student_id):
        self.phone_number=phone_number
        self.email_id=email_id
        self.student_id=student_id
    def return_student_deetails(self):
        return self.student_id,self.phone_number,self.email_id

# %%
rohan=skills1(7766554466,"rohan@gmail.com",101)

# %%
rohan.phone_number
# Out:
# 7766554466

# %%
gaurav=skills1(7766554456,"gaurav@gmail.com",102)

# %%
gaurav.phone_number
# Out:
# 7766554456

# %%
rohan.return_student_deetails()
# Out:
# (101, 7766554466, 'rohan@gmail.com')

# %%
gaurav.return_student_deetails()
# Out:
# (102, 7766554456, 'gaurav@gmail.com')

# %%
class skills2:
    def __init__(self,phone_number,email_id,student_id):
        self.phone_number1=phone_number
        self.email_id1=email_id
        self.student_id1=student_id
    def return_student_deetails(self):
        return self.student_id1,self.phone_number1,self.email_id1

# %%
sudha = skills2(7766554436,"sudh@gmail.com",131)

# %%
sudha.phone_number1
# Out:
# 7766554436

# %%
sudha.return_student_deetails()
# Out:
# (131, 7766554436, 'sudh@gmail.com')

# %%
class UPI:
  def pay(self):
    print("Paymrnt through UPI")
class Card:
  def pay(self):
    print("Payment through Card")
for payment in [UPI(),Card()]:
  payment.pay()
# Out:
# Paymrnt through UPI
# Payment through Card

# %%
name="dev"
password=2345
Name=input("Enter your name")
if name==Name:
  password=int(input("Enter your password"))
  if password==2345:
    print("Welcome to the tracker")
else:
  print("wrong info entered")
# Out:
# Enter your namedeep
# wrong info entered

# %%
users = {}


n = int(input("How many users do you want to add? "))

for i in range(n):
    name = input("Enter username: ")
    password = int(input("Enter password: "))
    users[name] = password

print("\nUsers saved successfully!")


print("\n----- LOGIN -----")
login_name = input("Enter your username: ")

if login_name in users:
    login_password = int(input("Enter your password: "))

    if users[login_name] == login_password:
        print("Welcome to the tracker!")
        Expense = input("Enter your expense: Cloathing,Food,Travling:-")

        match Expense:
          case "Cloathing":
            print("Cloathing")
          case "Food":
            Expensefood=int(input("enter the expense on the fooding items"))
            print(Expensefood)
          case "Travling":
            print("Travling")
          case _:
            print("Invalid input")



    else:
        print("Incorrect password.")
else:
    print("Username not found.")
# Out:
# How many users do you want to add? 1
# Enter username: de
# Enter password: 3
#
# Users saved successfully!
#
# ----- LOGIN -----
# Enter your username: de
# Enter your password: 3
# Welcome to the tracker!
# Enter your expense: Cloathing,Food,TravlingFood
# Food
